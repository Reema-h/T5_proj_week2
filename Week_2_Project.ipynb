# %% [markdown]
# <a href="https://colab.research.google.com/github/Reema-h/T5_proj_week2/blob/main/Week_2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Weekly Project 2!

# %% [markdown]
# ## Introduction to Road Traffic Accidents (RTA) Dataset
#
# ### Dataset Overview
# The RTA Dataset provides a detailed snapshot of road traffic accidents, capturing a range of data from accident conditions to casualty details. This dataset is essential for analyzing patterns and causes of accidents to improve road safety.
#
# ### Data Characteristics
# - **Entries**: The dataset contains 12,316 entries.
# - **Features**: There are 32 features in the dataset, which include:
#   - `Time`: Time when the accident occurred.
#   - `Day_of_week`: Day of the week.
#   - `Age_band_of_driver`: Age group of the driver involved.
#   - `Sex_of_driver`: Gender of the driver.
#   - `Educational_level`: Educational level of the driver.
#   - `Type_of_vehicle`: Type of vehicle involved in the accident.
#   - `Cause_of_accident`: Reported cause of the accident.
#   - `Accident_severity`: Severity of the accident.
# - **Target Column**: `Accident_severity` is used as the target column for modeling. This feature classifies the severity of each accident.
#
# ### Objective
# Students will use this dataset to apply various data visualization, modeling, and evaluation techniques learned in class. The primary goal is to build models that can accurately predict the severity of accidents and to identify the key factors that contribute to severe accidents.

# %% [markdown]
# ## Import Libraries
# Import all the necessary libraries here. Include libraries for handling data (like pandas), visualization (like matplotlib and seaborn), and modeling (like scikit-learn).

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Load Data
# Load the dataset from the provided CSV file into a DataFrame.

# %%
df = pd.read_csv('/content/RTA_Dataset.csv')
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0               Automobile            Owner              Above 10yr  ...
# 1      Public (> 45 seats)            Owner                 5-10yrs  ...
# 2          Lorry (41?100Q)            Owner                     NaN  ...
# 3      Public (> 45 seats)     Governmental                     NaN  ...
# 4                      NaN            Owner                 5-10yrs  ...
# ...                    ...              ...                     ...  ...
# 12311       Lorry (11?40Q)            Owner                     NaN  ...
# 12312           Automobile            Owner                     NaN  ...
# 12313                Bajaj            Owner                  2-5yrs  ...
# 12314      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315                Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0       Going straight               na              na                   na
# 1       Going straight               na              na                   na
# 2       Going straight  Driver or rider            Male                31-50
# 3       Going straight       Pedestrian          Female                18-30
# 4       Going straight               na              na                   na
# ...                ...              ...             ...                  ...
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                    na               NaN                  NaN
# 1                    na               NaN                  NaN
# 2                     3            Driver                  NaN
# 3                     3            Driver               Normal
# 4                    na               NaN                  NaN
# ...                 ...               ...                  ...
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 0                           Moving Backward     Slight Injury
# 1                                Overtaking     Slight Injury
# 2                 Changing lane to the left    Serious Injury
# 3                Changing lane to the right     Slight Injury
# 4                                Overtaking     Slight Injury
# ...                                     ...               ...
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [12316 rows x 32 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
#  13  Road_allignment              12174 non-null  object
#  14  Types_of_Junction            11429 non-null  object
#  15  Road_surface_type            12144 non-null  object
#  16  Road_surface_conditions      12316 non-null  object
#  17  Light_conditions             12316 non-null  object
#  18  Weather_conditions           12316 non-null  object
#  19  Type_of_collision            12161 non-null  object
#  20  Number_of_vehicles_involved  12316 non-null  int64
#  21  Number_of_casualties         12316 non-null  int64
#  22  Vehicle_movement             12008 non-null  object
#  23  Casualty_class               12316 non-null  object
#  24  Sex_of_casualty              12316 non-null  object
#  25  Age_band_of_casualty         12316 non-null  object
#  26  Casualty_severity            12316 non-null  object
#  27  Work_of_casuality            9118 non-null   object
#  28  Fitness_of_casuality         9681 non-null   object
#  29  Pedestrian_movement          12316 non-null  object
#  30  Cause_of_accident            12316 non-null  object
#  31  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(30)
# memory usage: 3.0+ MB

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# 12312       Automobile            Owner                     NaN  ...
# 12313            Bajaj            Owner                  2-5yrs  ...
# 12314  Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315            Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 3769   13:40:00      Sunday            Over 51          Male
# 9994   12:30:00    Thursday              18-30          Male
# 2905   18:46:00   Wednesday              18-30          Male
# 3554   18:01:00      Monday            Unknown        Female
# 10945  23:35:00   Wednesday              31-50          Male
# 9263   15:45:00      Friday              18-30          Male
# 8601   17:55:00      Monday              18-30          Male
# 6109   22:16:00   Wednesday              18-30          Male
# 7091    8:45:00      Monday              31-50          Male
# 349    12:46:00      Friday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 3769   Junior high school                Employee              2-5yr
# 9994   Junior high school                Employee          Below 1yr
# 2905   Junior high school                Employee         Above 10yr
# 3554   Junior high school                Employee             5-10yr
# 10945  Junior high school                Employee             5-10yr
# 9263    Elementary school                Employee              1-2yr
# 8601   Junior high school                Employee              1-2yr
# 6109   Junior high school                     NaN             5-10yr
# 7091    Elementary school                Employee              1-2yr
# 349                   NaN                     NaN                NaN
#
#             Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 3769                Bicycle            Owner                 Unknown  ...
# 9994                  Other            Owner                 Unknown  ...
# 2905   Public (13?45 seats)            Owner                   1-2yr  ...
# 3554           Stationwagen            Owner                 Unknown  ...
# 10945      Pick up upto 10Q            Owner                     NaN  ...
# 9263        Special vehicle     Governmental                   1-2yr  ...
# 8601        Lorry (41?100Q)            Owner                     NaN  ...
# 6109         Lorry (11?40Q)            Owner                 Unknown  ...
# 7091             Automobile              NaN                     NaN  ...
# 349                     NaN              NaN                     NaN  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 3769         Reversing  Driver or rider            Male             Under 18
# 9994    Going straight  Driver or rider            Male                31-50
# 2905   Moving Backward               na              na                   na
# 3554    Going straight               na              na                   na
# 10945            Other  Driver or rider            Male                18-30
# 9263         Reversing        Passenger          Female                18-30
# 8601    Going straight  Driver or rider          Female              Over 51
# 6109   Moving Backward               na              na                   na
# 7091    Going straight               na              na                   na
# 349     Going straight               na              na                   na
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 3769                  3            Driver               Normal
# 9994                  3            Driver               Normal
# 2905                 na            Driver               Normal
# 3554                 na            Driver               Normal
# 10945                 3     Self-employed               Normal
# 9263                  3            Driver               Normal
# 8601                  3             Other               Normal
# 6109                 na            Driver               Normal
# 7091                 na            Driver               Normal
# 349                  na               NaN               Normal
#
#       Pedestrian_movement                   Cause_of_accident  \
# 3769     Not a Pedestrian                       No distancing
# 9994     Not a Pedestrian                       No distancing
# 2905     Not a Pedestrian                               Other
# 3554     Not a Pedestrian          Changing lane to the right
# 10945    Not a Pedestrian              No priority to vehicle
# 9263     Not a Pedestrian                       No distancing
# 8601     Not a Pedestrian                     Moving Backward
# 6109     Not a Pedestrian                       No distancing
# 7091     Not a Pedestrian          Changing lane to the right
# 349      Not a Pedestrian  Getting off the vehicle improperly
#
#       Accident_severity
# 3769      Slight Injury
# 9994      Slight Injury
# 2905      Slight Injury
# 3554      Slight Injury
# 10945    Serious Injury
# 9263      Slight Injury
# 8601      Slight Injury
# 6109     Serious Injury
# 7091      Slight Injury
# 349       Slight Injury
#
# [10 rows x 32 columns]

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is essential for transforming raw data into a format suitable for further analysis and modeling. Follow these steps to ensure your data is ready for predictive modeling or advanced analytics:
# - **Handling Missing Values**: Replace missing values with appropriate statistics (mean, median, mode) or use more complex imputation techniques.
# - **Normalization/Scaling**: Scale data to a small, specified range like 0 to 1, or transform it to have a mean of zero and a standard deviation of one.
# - **Label Encoding**: Convert categorical text data into model-understandable numbers where the labels are ordered.
# - **One-Hot Encoding**: Use for nominal categorical data where no ordinal relationship exists to transform the data into a binary column for each category. (Be careful not to increase the dimensionality significantly)
# - **Detection and Treatment of Outliers**: Use statistical tests, box plots, or scatter plots to identify outliers and then cap, trim, or use robust methods to reduce the effect of outliers, depending on the context.
# - **Feature Engineering**: Enhance your dataset by creating new features and transforming existing ones. This might involve combining data from different columns, applying transformations, or reducing dimensionality with techniques like PCA to improve model performance.
#
# Consider these steps as a foundation, and feel free to introduce additional preprocessing techniques as needed to address specific characteristics of your dataset.

# %%
df = df.replace('na', np.nan)
df = df.replace('Unknown', np.nan)
df.sample(10)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 589   17:23:00     Tuesday              31-50           NaN
# 3327  14:36:00      Sunday              31-50          Male
# 1777   8:00:00     Tuesday                NaN          Male
# 1888  17:35:00     Tuesday              18-30          Male
# 1277   7:22:00    Thursday              18-30           NaN
# 2598  10:05:00    Thursday              31-50          Male
# 9415   8:15:00   Wednesday              31-50          Male
# 2234   8:21:00    Thursday              18-30          Male
# 605   18:40:00      Friday              18-30          Male
# 7407  16:10:00      Monday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 589          High school                   Owner         Above 10yr
# 3327  Junior high school                Employee              2-5yr
# 1777   Elementary school                   Owner         Above 10yr
# 1888         High school                Employee             5-10yr
# 1277  Junior high school                Employee          Below 1yr
# 2598  Junior high school                Employee             5-10yr
# 9415  Junior high school                Employee                NaN
# 2234  Junior high school                Employee              2-5yr
# 605                  NaN                   Owner         Above 10yr
# 7407   Elementary school                Employee             5-10yr
#
#           Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 589            Automobile            Owner                 5-10yrs  ...
# 3327                Other     Organization                     NaN  ...
# 1777                Other            Owner              Above 10yr  ...
# 1888                Other            Owner                     NaN  ...
# 1277                Other     Governmental                     NaN  ...
# 2598           Long lorry     Governmental                     NaN  ...
# 9415      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 2234  Public (> 45 seats)            Owner                 5-10yrs  ...
# 605                 Other     Organization                     NaN  ...
# 7407      Lorry (41?100Q)            Owner                     NaN  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 589    Going straight       Pedestrian            Male             Under 18
# 3327            Other  Driver or rider            Male                18-30
# 1777   Going straight        Passenger            Male                18-30
# 1888  Moving Backward       Pedestrian            Male              Over 51
# 1277   Going straight              NaN             NaN                  NaN
# 2598      Getting off       Pedestrian          Female                18-30
# 9415  Moving Backward  Driver or rider          Female                18-30
# 2234   Going straight              NaN             NaN                  NaN
# 605    Going straight  Driver or rider            Male                18-30
# 7407   Going straight  Driver or rider            Male                31-50
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 589                  2          Employee               Normal
# 3327                 3     Self-employed               Normal
# 1777                 3               NaN               Normal
# 1888                 2            Driver               Normal
# 1277               NaN            Driver               Normal
# 2598                 3     Self-employed               Normal
# 9415                 3            Driver               Normal
# 2234               NaN     Self-employed               Normal
# 605                  3               NaN                  NaN
# 7407                 3               NaN               Normal
#
#      Pedestrian_movement           Cause_of_accident Accident_severity
# 589     Not a Pedestrian                 Overturning     Slight Injury
# 3327    Not a Pedestrian                       Other     Slight Injury
# 1777    Not a Pedestrian               No distancing     Slight Injury
# 1888    Unknown or other      No priority to vehicle     Slight Injury
# 1277    Not a Pedestrian  Changing lane to the right    Serious Injury
# 2598    Not a Pedestrian          Driving carelessly     Slight Injury
# 9415    Not a Pedestrian               No distancing     Slight Injury
# 2234    Not a Pedestrian               No distancing     Slight Injury
# 605     Not a Pedestrian  Changing lane to the right     Slight Injury
# 7407    Not a Pedestrian   Changing lane to the left     Slight Injury
#
# [10 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver             1548
# Sex_of_driver                   178
# Educational_level               841
# Vehicle_driver_relation         593
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        6811
# Defect_of_vehicle              4427
# Area_accident_occured           261
# Lanes_or_Medians                442
# Road_allignment                 142
# Types_of_Junction              1078
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              292
# Type_of_collision               169
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                396
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# Casualty_severity              4443
# Work_of_casuality              3217
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                25
# Accident_severity                 0
# dtype: int64

# %%
df['Educational_level'].mode()
# Out:
# 0    Junior high school
# Name: Educational_level, dtype: object

# %%
df['Educational_level'].fillna('Junior high school', inplace= True)

# %%
df['Type_of_vehicle'].mode()
# Out:
# 0    Automobile
# Name: Type_of_vehicle, dtype: object

# %%
df['Type_of_vehicle'].fillna('Automobile', inplace=True)

# %%
df['Road_surface_conditions'].mode()
# Out:
# 0    Dry
# Name: Road_surface_conditions, dtype: object

# %%
df['Road_surface_conditions'].fillna('Dry', inplace=True)

# %%
df['Road_surface_type'].mode()
# Out:
# 0    Asphalt roads
# Name: Road_surface_type, dtype: object

# %%
df['Road_surface_type'].fillna('Asphalt roads', inplace= True)

# %%
df['Owner_of_vehicle'].mode()
# Out:
# 0    Owner
# Name: Owner_of_vehicle, dtype: object

# %%
df['Owner_of_vehicle'].fillna('Owner', inplace= True)

# %%
df['Area_accident_occured'].mode()
# Out:
# 0    Other
# Name: Area_accident_occured, dtype: object

# %%
df['Area_accident_occured'].fillna('Other', inplace= True)

# %%
df['Vehicle_movement'].mode()
# Out:
# 0    Going straight
# Name: Vehicle_movement, dtype: object

# %%
df['Vehicle_movement'].fillna('Going straight', inplace=True)

# %%
df.drop(columns= ['Vehicle_driver_relation','Driving_experience','Service_year_of_vehicle','Defect_of_vehicle','Fitness_of_casuality','Work_of_casuality'], inplace=True)

# %%
df['Weather_conditions'].mode()
# Out:
# 0    Normal
# Name: Weather_conditions, dtype: object

# %%
df['Weather_conditions'].fillna('Normal',inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver             1548
# Sex_of_driver                   178
# Educational_level                 0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Area_accident_occured             0
# Lanes_or_Medians                442
# Road_allignment                 142
# Types_of_Junction              1078
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               169
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# Casualty_severity              4443
# Pedestrian_movement               0
# Cause_of_accident                25
# Accident_severity                 0
# dtype: int64

# %%
df =df.dropna(how='any',axis=0)
df.reset_index()
# Out:
#       index      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0         3   1:06:00      Sunday              18-30          Male
# 1         6  17:30:00   Wednesday              18-30          Male
# 2         8  17:20:00      Friday              18-30          Male
# 3         9  17:20:00      Friday              18-30          Male
# 4        11  14:40:00    Saturday              31-50          Male
# ...     ...       ...         ...                ...           ...
# 5752  12305   7:10:00      Friday              18-30          Male
# 5753  12309   9:05:00      Friday              31-50        Female
# 5754  12310   9:05:00      Friday              18-30          Male
# 5755  12313  13:55:00      Sunday            Over 51          Male
# 5756  12315  13:55:00      Sunday              18-30          Male
#
#        Educational_level      Type_of_vehicle Owner_of_vehicle  \
# 0     Junior high school  Public (> 45 seats)     Governmental
# 1     Junior high school           Automobile            Owner
# 2     Junior high school      Lorry (41?100Q)            Owner
# 3     Junior high school           Automobile            Owner
# 4      Above high school           Automobile            Owner
# ...                  ...                  ...              ...
# 5752  Junior high school  Public (> 45 seats)            Owner
# 5753   Elementary school     Pick up upto 10Q            Owner
# 5754  Junior high school      Special vehicle            Owner
# 5755  Junior high school                Bajaj            Owner
# 5756  Junior high school                Other            Owner
#
#      Area_accident_occured                                  Lanes_or_Medians  \
# 0             Office areas                                             other
# 1        Residential areas                                 Undivided Two way
# 2         Industrial areas                                             other
# 3        Residential areas                                 Undivided Two way
# 4             Office areas                                 Undivided Two way
# ...                    ...                                               ...
# 5752   Outside rural areas  Two-way (divided with broken lines road marking)
# 5753          School areas                                             other
# 5754   Outside rural areas  Two-way (divided with broken lines road marking)
# 5755   Outside rural areas  Two-way (divided with broken lines road marking)
# 5756   Outside rural areas                                 Undivided Two way
#
#       ... Number_of_vehicles_involved Number_of_casualties Vehicle_movement  \
# 0     ...                           2                    2   Going straight
# 1     ...                           1                    1  Moving Backward
# 2     ...                           2                    1   Going straight
# 3     ...                           2                    1           U-Turn
# 4     ...                           2                    1   Going straight
# ...   ...                         ...                  ...              ...
# 5752  ...                           2                    1  Moving Backward
# 5753  ...                           2                    2   Going straight
# 5754  ...                           1                    1        Reversing
# 5755  ...                           1                    1            Other
# 5756  ...                           2                    1         Stopping
#
#        Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0          Pedestrian          Female                18-30                 3
# 1     Driver or rider          Female                18-30                 3
# 2          Pedestrian            Male             Under 18                 3
# 3           Passenger            Male                18-30                 3
# 4     Driver or rider            Male                18-30                 3
# ...               ...             ...                  ...               ...
# 5752        Passenger            Male              Over 51                 3
# 5753  Driver or rider            Male                18-30                 3
# 5754        Passenger            Male              Over 51                 3
# 5755  Driver or rider            Male                31-50                 3
# 5756       Pedestrian          Female                    5                 3
#
#                                     Pedestrian_movement  \
# 0                                      Not a Pedestrian
# 1                                      Not a Pedestrian
# 2                       Crossing from driver's nearside
# 3                                      Not a Pedestrian
# 4                                      Not a Pedestrian
# ...                                                 ...
# 5752                                   Not a Pedestrian
# 5753                                   Not a Pedestrian
# 5754                                   Not a Pedestrian
# 5755                                   Not a Pedestrian
# 5756  Crossing from nearside - masked by parked or s...
#
#                Cause_of_accident Accident_severity
# 0     Changing lane to the right     Slight Injury
# 1                          Other     Slight Injury
# 2     Changing lane to the right     Slight Injury
# 3                Moving Backward    Serious Injury
# 4      No priority to pedestrian    Serious Injury
# ...                          ...               ...
# 5752          Driving carelessly     Slight Injury
# 5753         Driving to the left     Slight Injury
# 5754   Changing lane to the left    Serious Injury
# 5755  Changing lane to the right    Serious Injury
# 5756  Changing lane to the right     Slight Injury
#
# [5757 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ## Data Visualization
# Create various plots to visualize the relationships in the data. Consider using the following to show different aspects of the data:
#
# * Heatmap of Correlation Matrix.
# * Line plots.
# * Scatter plots.
# * Histograms.
# * Boxplots.
#
# Use more if needed!

# %%
df.corr(numeric_only=True)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.234532
# Number_of_casualties                            0.234532              1.000000

# %%
df.plot.hist(bins=12, alpha=0.5);

# %%
sns.heatmap(df.corr(numeric_only=True),vmax= 0.5, annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 3       1:06:00      Sunday              18-30          Male
# 6      17:30:00   Wednesday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 11     14:40:00    Saturday              31-50          Male
# ...         ...         ...                ...           ...
# 12305   7:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12310   9:05:00      Friday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level      Type_of_vehicle Owner_of_vehicle  \
# 3      Junior high school  Public (> 45 seats)     Governmental
# 6      Junior high school           Automobile            Owner
# 8      Junior high school      Lorry (41?100Q)            Owner
# 9      Junior high school           Automobile            Owner
# 11      Above high school           Automobile            Owner
# ...                   ...                  ...              ...
# 12305  Junior high school  Public (> 45 seats)            Owner
# 12309   Elementary school     Pick up upto 10Q            Owner
# 12310  Junior high school      Special vehicle            Owner
# 12313  Junior high school                Bajaj            Owner
# 12315  Junior high school                Other            Owner
#
#       Area_accident_occured                                  Lanes_or_Medians  \
# 3              Office areas                                             other
# 6         Residential areas                                 Undivided Two way
# 8          Industrial areas                                             other
# 9         Residential areas                                 Undivided Two way
# 11             Office areas                                 Undivided Two way
# ...                     ...                                               ...
# 12305   Outside rural areas  Two-way (divided with broken lines road marking)
# 12309          School areas                                             other
# 12310   Outside rural areas  Two-way (divided with broken lines road marking)
# 12313   Outside rural areas  Two-way (divided with broken lines road marking)
# 12315   Outside rural areas                                 Undivided Two way
#
#                                      Road_allignment  ...  \
# 3      Tangent road with mild grade and flat terrain  ...
# 6                     Tangent road with flat terrain  ...
# 8                     Tangent road with flat terrain  ...
# 9                     Tangent road with flat terrain  ...
# 11                    Tangent road with flat terrain  ...
# ...                                              ...  ...
# 12305                 Tangent road with flat terrain  ...
# 12309  Steep grade downward with mountainous terrain  ...
# 12310                 Tangent road with flat terrain  ...
# 12313      Tangent road with mountainous terrain and  ...
# 12315      Tangent road with mountainous terrain and  ...
#
#       Number_of_vehicles_involved Number_of_casualties Vehicle_movement  \
# 3                               2                    2   Going straight
# 6                               1                    1  Moving Backward
# 8                               2                    1   Going straight
# 9                               2                    1           U-Turn
# 11                              2                    1   Going straight
# ...                           ...                  ...              ...
# 12305                           2                    1  Moving Backward
# 12309                           2                    2   Going straight
# 12310                           1                    1        Reversing
# 12313                           1                    1            Other
# 12315                           2                    1         Stopping
#
#         Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 3           Pedestrian          Female                18-30
# 6      Driver or rider          Female                18-30
# 8           Pedestrian            Male             Under 18
# 9            Passenger            Male                18-30
# 11     Driver or rider            Male                18-30
# ...                ...             ...                  ...
# 12305        Passenger            Male              Over 51
# 12309  Driver or rider            Male                18-30
# 12310        Passenger            Male              Over 51
# 12313  Driver or rider            Male                31-50
# 12315       Pedestrian          Female                    5
#
#        Casualty_severity                                Pedestrian_movement  \
# 3                      3                                   Not a Pedestrian
# 6                      3                                   Not a Pedestrian
# 8                      3                    Crossing from driver's nearside
# 9                      3                                   Not a Pedestrian
# 11                     3                                   Not a Pedestrian
# ...                  ...                                                ...
# 12305                  3                                   Not a Pedestrian
# 12309                  3                                   Not a Pedestrian
# 12310                  3                                   Not a Pedestrian
# 12313                  3                                   Not a Pedestrian
# 12315                  3  Crossing from nearside - masked by parked or s...
#
#                 Cause_of_accident Accident_severity
# 3      Changing lane to the right     Slight Injury
# 6                           Other     Slight Injury
# 8      Changing lane to the right     Slight Injury
# 9                 Moving Backward    Serious Injury
# 11      No priority to pedestrian    Serious Injury
# ...                           ...               ...
# 12305          Driving carelessly     Slight Injury
# 12309         Driving to the left     Slight Injury
# 12310   Changing lane to the left    Serious Injury
# 12313  Changing lane to the right    Serious Injury
# 12315  Changing lane to the right     Slight Injury
#
# [5757 rows x 26 columns]

# %% [markdown]
# ## Feature Selection
# - Choose features that you believe will most influence the outcome based on your analysis and the insights from your visualizations. Focus on those that appear most impactful to include in your modeling.
#
# ## Train-Test Split
# * Divide the dataset into training and testing sets to evaluate the performance of your models.

# %%
X_features = df[['Time','Day_of_week','Age_band_of_driver','Sex_of_driver','Educational_level','Type_of_vehicle','Cause_of_accident']]
y_target =df['Accident_severity']
X_train, X_test, y_train, y_text = train_test_split(X,y, test_size=0.3)

# %% [markdown]
# ## Modeling
#
# Once the data is split into training and testing sets, the next step is to build models to make predictions. Here, we will explore several machine learning algorithms, each with its unique characteristics and suitability for different types of data and problems. You will implement the following models:
#
# ### 1. Logistic Regression
#
# ### 2. Decision Tree Classifier
#
# ### 3. Support Vector Machine (SVM)
#
# ### 4. K-Neighbors Classifier
#
# ### Implementing the Models
# - For each model, use the training data you have prepared to train the model.

# %% [markdown]
# #### Logistic Regression

# %%
log_reg = LogisticRegression(penalty="l1",
    solver="liblinear",
    tol=1e-6,
    max_iter=1000,)
log_reg.fit(X_features,y_target)
#log_reg.predict(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-857-cb923903fe15> in <cell line: 5>()
#       3     tol=1e-6,
#       4     max_iter=1000,)
# ----> 5 log_reg.fit(X_features,y_target)
#       6 #log_reg.predict(y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620                 y = check_array(y, input_name="y", **check_y_params)
#     621             else:
# --> 622                 X, y = check_X_y(X, y, **check_params)
#     623             out = X, y
#     624
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1144         )
#    1145
# -> 1146     X = check_array(
#    1147         X,
#    1148         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: '1:06:00'

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtr_clf = DecisionTreeClassifier(max_depth=2)

dtr_clf.fit(X_features,y_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-858-07cbc8edf6e6> in <cell line: 4>()
#       2 dtr_clf = DecisionTreeClassifier(max_depth=2)
#       3
# ----> 4 dtr_clf.fit(X_features,y_target)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     957         """
#     958
# --> 959         super()._fit(
#     960             X,
#     961             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     240             )
#     241             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 242             X, y = self._validate_data(
#     243                 X, y, validate_separately=(check_X_params, check_y_params)
#     244             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     615                 if "estimator" not in check_X_params:
#     616                     check_X_params = {**default_check_params, **check_X_params}
# --> 617                 X = check_array(X, input_name="X", **check_X_params)
#     618                 if "estimator" not in check_y_params:
#     619                     check_y_params = {**default_check_params, **check_y_params}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: '1:06:00'

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
classifier = svm.SVC(kernel="linear", C=0.01).fit(X_train, y_train)

# %% [markdown]
# #### K-Neighbors Classifier

# %%
knn_clf = KNeighborsClassifier(weights='distance')
knn_clf.fit(X_features,y_target)
y_pred = knn_clf.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-859-f590f469b398> in <cell line: 2>()
#       1 knn_clf = KNeighborsClassifier(weights='distance')
# ----> 2 knn_clf.fit(X_features,y_target)
#       3 y_pred = knn_clf.predict()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     231             The fitted k-nearest neighbors classifier.
#     232         """
# --> 233         return self._fit(X, y)
#     234
#     235     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     454         if self._get_tags()["requires_y"]:
#     455             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 456                 X, y = self._validate_data(
#     457                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     458                 )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620                 y = check_array(y, input_name="y", **check_y_params)
#     621             else:
# --> 622                 X, y = check_X_y(X, y, **check_params)
#     623             out = X, y
#     624
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1144         )
#    1145
# -> 1146     X = check_array(
#    1147         X,
#    1148         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: '1:06:00'

# %% [markdown]
# ## Model Evaluation
#
# After training your models, it's crucial to evaluate their performance to understand their effectiveness and limitations. This section outlines various techniques and metrics to assess the performance of each model you have implemented.
#
# ### Evaluation Techniques
# 1. **Confusion Matrix**
#
# 2. **Accuracy**
#
# 3. **Precision and Recall**
#
# 4. **F1 Score**
#
# 5. **ROC Curve and AUC**
#
# ### Implementing Evaluation
# - Calculate the metrics listed above using your test data.

# %%
knn_clf.confusion_matrix(y_train, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-860-dc9c1fa54680> in <cell line: 1>()
# ----> 1 knn_clf.confusion_matrix(y_train, y_pred)
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'confusion_matrix'

# %% [markdown]
# ## Project Questions:
#
# ### Comparative Analysis
#
# - **Compare Metrics**: Examine the performance metrics (such as accuracy, precision, and recall) of each model. Document your observations on which model performs best for your dataset and the problem you're addressing.
# - **Evaluate Trade-offs**: Discuss the trade-offs you encountered when choosing between models. Consider factors like computational efficiency, ease of implementation, and model interpretability.
# - **Justify Your Choice**: After comparing and evaluating, explain why you believe one model is the best choice. Provide a clear rationale based on the performance metrics and trade-offs discussed.
# - **Feature Importance**: Identify and discuss the most important features for the best-performing model. How do these features impact the predictions? Use the visualizations you have created to justify your answer if necessary.
# - **Model Limitations**: Discuss any limitations you encountered with the models you used. Are there any aspects of the data or the problem that these models do not handle well?
# - **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. This could include trying different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:
